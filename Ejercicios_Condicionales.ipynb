# %%
# Ejercicio 1: Indicar si un número es positivo
num = float(input("Ingrese un número: "))
if num > 0:
    print("El número es positivo")

# %%
# Ejercicio 2: Número mayor que 100
num = float(input("Ingrese un número: "))
if num > 100:
    print("El número es mayor que 100")

# %%
# Ejercicio 3: Mayor de edad
edad = int(input("Ingrese su edad: "))
if edad >= 18:
    print("Es mayor de edad")

# %%
# Ejercicio 4: Validar contraseña
clave = input("Ingrese la contraseña: ")
if clave == "admin123":
    print("Contraseña correcta")

# %%
# Ejercicio 5: Nota mayor o igual a 7
nota = float(input("Ingrese la nota: "))
if nota >= 7:
    print("Aprobado")

# %%
# Ejercicio 6: Número par
num = int(input("Ingrese un número: "))
if num % 2 == 0:
    print("Es par")

# %%
# Ejercicio 7: Temperatura mayor a 38
temp = float(input("Ingrese la temperatura: "))
if temp > 38:
    print("Alerta: Fiebre alta")

# %%
# Ejercicio 8: Salario mayor al mínimo (365 USD ejemplo)
salario = float(input("Ingrese su salario: "))
if salario > 365:
    print("Supera el salario mínimo")

# %%
# Ejercicio 9: Verificar vocal
letra = input("Ingrese una letra: ").lower()
if letra in "aeiou":
    print("Es vocal")

# %%
# Ejercicio 10: Hora menor a 12
hora = int(input("Ingrese la hora (0-23): "))
if hora < 12:
    print("Es antes del mediodía")

# %%
# Ejercicio 11: Positivo o negativo
num = float(input("Ingrese un número: "))
if num >= 0:
    print("Positivo")
else:
    print("Negativo")

# %%
# Ejercicio 12: Mayor o menor de edad
edad = int(input("Ingrese su edad: "))
if edad >= 18:
    print("Mayor de edad")
else:
    print("Menor de edad")

# %%
# Ejercicio 13: Acceso concedido o denegado
clave = input("Ingrese la clave: ")
if clave == "admin123":
    print("Acceso concedido")
else:
    print("Acceso denegado")

# %%
# Ejercicio 14: Par o impar
num = int(input("Ingrese un número: "))
if num % 2 == 0:
    print("Par")
else:
    print("Impar")

# %%
# Ejercicio 15: Aprobado o reprobado
nota = float(input("Ingrese la nota: "))
if nota >= 7:
    print("Aprobado")
else:
    print("Reprobado")

# %%
# Ejercicio 16: Mayor o menor que 50
num = float(input("Ingrese un número: "))
if num > 50:
    print("Mayor que 50")
else:
    print("Menor o igual a 50")

# %%
# Ejercicio 17: Año mayor o menor que 2000
anio = int(input("Ingrese un año: "))
if anio > 2000:
    print("Es posterior al 2000")
else:
    print("Es del 2000 o anterior")

# %%
# Ejercicio 18: Aplicar descuento
precio = float(input("Ingrese el precio: "))
if precio > 100:
    print("Aplica descuento")
else:
    print("No aplica descuento")

# %%
# Ejercicio 19: Verificar si es letra
car = input("Ingrese un carácter: ")
if car.isalpha():
    print("Es una letra")
else:
    print("No es una letra")

# %%
# Ejercicio 20: Puede votar
edad = int(input("Ingrese su edad: "))
if edad >= 18:
    print("Puede votar")
else:
    print("No puede votar")

# %%
# Ejercicio 21: Negativo, cero o positivo
num = float(input("Ingrese un número: "))
if num < 0:
    print("Negativo")
elif num == 0:
    print("Cero")
else:
    print("Positivo")

# %%
# Ejercicio 22: Nota baja, media o alta
nota = float(input("Ingrese la nota (0-10): "))
if nota < 5:
    print("Baja")
elif nota < 8:
    print("Media")
else:
    print("Alta")

# %%
# Ejercicio 23: Niño, adolescente o adulto
edad = int(input("Ingrese la edad: "))
if edad < 12:
    print("Niño")
elif edad < 18:
    print("Adolescente")
else:
    print("Adulto")

# %%
# Ejercicio 24: Múltiplo de 3 o 5
num = int(input("Ingrese un número: "))
if num % 3 == 0:
    print("Múltiplo de 3")
elif num % 5 == 0:
    print("Múltiplo de 5")
else:
    print("No es múltiplo de 3 ni de 5")

# %%
# Ejercicio 25: Temperatura
temp = float(input("Ingrese la temperatura: "))
if temp < 15:
    print("Frío")
elif temp <= 25:
    print("Templado")
else:
    print("Caliente")

# %%
# Ejercicio 26: Calificación cualitativa
nota = float(input("Ingrese la calificación: "))
if nota >= 9:
    print("Excelente")
elif nota >= 7:
    print("Bueno")
else:
    print("Insuficiente")

# %%
# Ejercicio 27: Mañana, tarde o noche
hora = int(input("Ingrese la hora (0-23): "))
if hora < 12:
    print("Mañana")
elif hora < 18:
    print("Tarde")
else:
    print("Noche")

# %%
# Ejercicio 28: Día de la semana
num = int(input("Ingrese un número del 1 al 7: "))
dias = ["Lunes","Martes","Miércoles","Jueves","Viernes","Sábado","Domingo"]
if 1 <= num <= 7:
    print(dias[num-1])
else:
    print("Número inválido")

# %%
# Ejercicio 29: Vocal, consonante o no válida
letra = input("Ingrese una letra: ").lower()
if not letra.isalpha() or len(letra) != 1:
    print("No válida")
elif letra in "aeiou":
    print("Vocal")
else:
    print("Consonante")

# %%
# Ejercicio 30: Rango numérico
num = float(input("Ingrese un número: "))
if num < 0:
    print("Menor que 0")
elif num <= 100:
    print("Entre 0 y 100")
else:
    print("Mayor que 100")
